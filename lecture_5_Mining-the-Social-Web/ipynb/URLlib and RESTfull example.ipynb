# %% [markdown]
# ## A demonstration of using urllib2 and a REST interface
#
# Here we demonstrate how to use a REST interface directly.
#
# We are using a data feed generated by the company [Decibel](http://www.decibel.net/) a company that provides data about the music industry.
#
# The REST API for Decibel is documented [here](https://developer.decibel.net/rest-api-v3)
#
# This demo is adapted from [this page](https://developer.decibel.net/sample-code-rest-python)
#
# urllib2 is described [here]
#
# In order to use the site you need to register and get an ID and a key. We did so and we stored
# the ID and key in a pickle file, which is located in the Vault directory - **This directory must never be shared, it contains your identity information**

# %%
# We start with a simple stand-alone piece of code.

from urllib2 import Request, urlopen, URLError

request = Request('http://placekitten.com/')

try:
	response = urlopen(request)
	kittens = response.read()
	print kittens[559:1000]
except URLError, e:
    print 'No kittez. Got an error code:', e
# Out:
#                       __     __,
#                       \,`~"~` /
#       .-=-.           /    . .\
#      / .-. \          {  =    Y}=
#     (_/   \ \          \      /
#            \ \        _/`'`'`b
#             \ `.__.-'`        \-._
#              |            '.__ `'-;_
#              |            _.' `'-.__)
#               \    ;_..-`'/     //  \
#               |   /  /   |     //    |
#               \  \ \__)   \   //    /
#                \__)

# %%
import requests
r = requests.get('http://placekitten.com/')
print r.content[559:1000]
# Out:
#                       __     __,
#                       \,`~"~` /
#       .-=-.           /    . .\
#      / .-. \          {  =    Y}=
#     (_/   \ \          \      /
#            \ \        _/`'`'`b
#             \ `.__.-'`        \-._
#              |            '.__ `'-;_
#              |            _.' `'-.__)
#               \    ;_..-`'/     //  \
#               |   /  /   |     //    |
#               \  \ \__)   \   //    /
#                \__)

# %%
# %cd DecibelPython27
import settings
print 'ID=',settings.applicationID,'key=',settings.applicationKey

# %%
import requests
# Set the request authentication headers
timestamp = datetime.datetime.fromtimestamp(time.time()).strftime('%Y%m%d %H:%M:%S')
headers['DecibelTimestamp']= timestamp
print headers

url = 'http://api.decibel.net/v1/Albums/?artist=miles%20davis&format=json'      
r = requests.get(url, headers=headers) # auth=keypair)
print r.content

# %%
# %pdb on
import util
import json
import urllib
import sys,traceback,pdb

applicationID, applicationKey = 'f36df815','0fefe10b09cfe5c414ed40e20e0c5ff8'

# Set the request URL
url = 'http://api.decibel.net/v1/Albums/?artist=' + urllib.quote_plus(artistName) + '&format=json'
# Out:
# Automatic pdb calling has been turned ON
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-fa7412b72a86> in <module>()
#       1 get_ipython().magic(u'pdb on')
# ----> 2 import util
#       3 import json
#       4 import urllib
#       5 import sys,traceback,pdb
#
# ImportError: No module named util
# > <ipython-input-1-fa7412b72a86>(2)<module>()
#       1 get_ipython().magic(u'pdb on')
# ----> 2 import util
#       3 import json

# %%
try:
    # Send the GET request
    resp = util.request(url,applicationID, applicationKey)

    # Interpret the JSON response
    raw = resp.decode('utf8')
    data = json.loads(raw)
except URLError, e:
    print 'Got an error code:', e
    exc_type, exc_value, exc_traceback = sys.exc_info()
    traceback.print_exception(exc_type, exc_value, exc_traceback,
                              limit=10, file=sys.stdout)
    pdb.set_trace()

# Get the collection of albums from the result set
albums = data['ResultSet']

# Output the search results
for album in albums:
    print(album['Name'] + ' - ' + album['Artists'])

# %%
# !ls

# %%
# After you get the credentials, place them as a Pickle file in the Vault
headers = {'DecibelAppID': 'f36df815', 
           'DecibelAppKey': '0fefe10b09cfe5c414ed40e20e0c5ff8'} 
#           'Web-Site': 'http://www.decibel.net/'}

import pickle
pickle.dump(headers,open('/Users/yoavfreund/.Vault/Decibel.pkl','w'))

# %%
# %%writefile util.py
import time
import datetime
import urllib2

def request(url, applicationID, applicationKey):
	
	# Set the request authentication headers
	timestamp = datetime.datetime.fromtimestamp(time.time()).strftime('%Y%m%d %H:%M:%S')
	headers = {'DecibelAppID': applicationID,
                   'DecibelAppKey': applicationKey,
                   'DecibelTimestamp': timestamp}

	# Send the GET request
	req = urllib2.Request(url, None, headers)

	# Read the response
	return urllib2.urlopen(req).read()
	
def formatTime(seconds):
	
	return time.strftime('%H:%M:%S', time.gmtime(seconds))
# Out:
# Writing util.py

# %%
#%%writefile DecibalRest.py
# -*- coding: utf-8 -*-

import urllib2
import time
import datetime
import pickle

headers=pickle.load(open('/Users/yoavfreund/.Vault/Decibel.pkl','r'))

# Set the request authentication headers
timestamp = datetime.datetime.fromtimestamp(time.time()).strftime('%Y%m%d %H:%M:%S')
headers['DecibelTimestamp']= timestamp

print headers

# Send the GET request
url = 'http://api.decibel.net/v1/Albums/?artist=miles%20davis&format=json'      
req = urllib2.Request(url, None, headers)

# Read the response
resp = urllib2.urlopen(req).read()

resp
# Out:
# {'DecibelAppID': 'f36df815', 'DecibelAppKey': '0fefe10b09cfe5c414ed40e20e0c5ff8', 'DecibelTimestamp': '20141120 11:00:53'}
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-17-70023e27400d> in <module>()
#      20
#      21 # Read the response
# ---> 22 resp = urllib2.urlopen(req).read()
#      23
#      24 resp
#
# //anaconda/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout)
#     125     if _opener is None:
#     126         _opener = build_opener()
# --> 127     return _opener.open(url, data, timeout)
#     128
#     129 def install_opener(opener):
#
# //anaconda/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     402             req = meth(req)
#     403
# --> 404         response = self._open(req, data)
#     405
#     406         # post-process response
#
# //anaconda/lib/python2.7/urllib2.pyc in _open(self, req, data)
# ...

# %%
import util
import json
import urllib

artistName='Bob Dylan'
# Set the request URL
url = 'http://api.decibel.net/v1/Albums/?artist=' + urllib.quote_plus(artistName) + '&format=json'

# Send the GET request
resp = util.request(url, headers['DecibelAppID'], headers['DecibelAppKey'])

# Interpret the JSON response 
data = json.loads(resp.decode('utf8'))

# Get the collection of albums from the result set
albums = data['ResultSet']

# Output the search results
for album in albums:
    print(album['Name'] + ' - ' + album['Artists'])
# Out:
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-19-c31d36cf8102> in <module>()
#       8
#       9 # Send the GET request
# ---> 10 resp = util.request(url, headers['DecibelAppID'], headers['DecibelAppKey'])
#      11
#      12 # Interpret the JSON response
#
# /Users/yoavfreund/academic.papers/Courses/DSE200/Imported_Noteboook_Collections/Mining-the-Social-Web-2nd-Edition/ipynb/util.py in request(url, applicationID, applicationKey)
#      15
#      16         # Read the response
# ---> 17         return urllib2.urlopen(req).read()
#      18
#      19 def formatTime(seconds):
#
# //anaconda/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout)
#     125     if _opener is None:
#     126         _opener = build_opener()
# --> 127     return _opener.open(url, data, timeout)
#     128
#     129 def install_opener(opener):
#
# ...
